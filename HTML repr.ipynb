# %%
# Generating HTML repr
import arviz as az
data = az.load_arviz_data('centered_eight')
import xarray
xarray.set_options(display_style="html")
data.posterior
# Out:
# <xarray.Dataset>
# Dimensions:  (chain: 4, draw: 500, school: 8)
# Coordinates:
#   * chain    (chain) int64 0 1 2 3
#   * draw     (draw) int64 0 1 2 3 4 5 6 7 8 ... 492 493 494 495 496 497 498 499
#   * school   (school) object 'Choate' 'Deerfield' ... "St. Paul's" 'Mt. Hermon'
# Data variables:
#     mu       (chain, draw) float64 ...
#     theta    (chain, draw, school) float64 ...
#     tau      (chain, draw) float64 ...
# Attributes:
#     created_at:                 2019-06-21T17:36:34.398087
#     inference_library:          pymc3
#     inference_library_version:  3.7

# %%
html_template = """
<div>
  <div class='xr-header'>
    <div class="xr-obj-type">arviz.InferenceData</div>
    <div class="xr-obj-type"><b>centered-eight</b></div>
  </div>
  {}
</div>
"""
element_temp ='''
<ul class="xr-sections">
<li class = "xr-section-item">
      <input id="xr-dataset-coord_{0}" class="xr-section-summary-in" type="checkbox">
      <label for="xr-dataset-coord_{0}" class = "xr-section-summary">{0}</label>
      <div class="xr-section-inline-details"></div>
      <div class="xr-section-details">
          <ul id="xr-dataset-coord-list" class="xr-var-list">
              <div>{1}</div>
          </ul>
      </div>
</li>
</ul>
'''
css_template = "<style>" + xarray.core.formatting_html.CSS_STYLE + ".xr-wrap{width:700px!important;}" + "</style>"

# %%
template = ""
elements=""
for data_group in data._groups:
    func = getattr(data,data_group)
    elements += element_temp.format(data_group, func._repr_html_())
template += html_template.format(elements) 
template += css_template

# %%
class HTML_example:
    
    def _repr_html_(self):
        return template

ex = HTML_example()
ex
# Out:
# <div>
#   <div class='xr-header'>
#     <div class="xr-obj-type">arviz.InferenceData</div>
#     <div class="xr-obj-type"><b>centered-eight</b></div>
#   </div>
#
# <ul class="xr-sections">
# <li class = "xr-section-item">
#       <input id="xr-dataset-coord_posterior" class="xr-section-summary-in" type="checkbox">
#       <label for="xr-dataset-coord_posterior" class = "xr-section-summary">posterior</label>
#       <div class="xr-section-inline-details"></div>
#       <div class="xr-section-details">
#           <ul id="xr-dataset-coord-list" class="xr-var-list">
#               <div><div><svg style="position: absolute; width: 0; height: 0; overflow: hidden">
# <defs>
# <symbol id="icon-database" viewBox="0 0 32 32">
# <title>Show/Hide data repr</title>
# <path d="M16 0c-8.837 0-16 2.239-16 5v4c0 2.761 7.163 5 16 5s16-2.239 16-5v-4c0-2.761-7.163-5-16-5z"></path>
# <path d="M16 17c-8.837 0-16-2.239-16-5v6c0 2.761 7.163 5 16 5s16-2.239 16-5v-6c0 2.761-7.163 5-16 5z"></path>
# ...
